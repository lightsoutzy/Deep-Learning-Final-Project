# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Dataset'
if os.path.exists(path):
    print("Directory exists")
else:
    print("Directory does not exist")
# Out:
# Directory exists

# %%
os.listdir('/content/drive/MyDrive/Colab Notebooks/Dataset')
# Out:
# ['white_spot',
#  'gray_blight',
#  'red_spot',
#  'anthracnose',
#  'brown_blight',
#  'helopeltis',
#  'healthy',
#  'bird_eye_spot',
#  'algal_spot']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.metrics import classification_report
import pathlib

# %%
dataset_dir = pathlib.Path(path)

# %%
class_names = []
for x in os.walk(path):
    sub_dir = x[0]
    sub_dir_list = str(sub_dir).split('/')
    if len(sub_dir_list) > 6:
        x_class = (sub_dir_list[-1])
        class_names.append(x_class)

print(class_names)
# Out:
# ['white_spot', 'gray_blight', 'red_spot', 'anthracnose', 'brown_blight', 'helopeltis', 'healthy', 'bird_eye_spot', 'algal_spot']

# %%
for class_i in class_names:
    image_count = len(list(dataset_dir.glob(f'{class_i}/*.png')))
    print(f"Images in class {class_i}:",image_count)
# Out:
# Images in class white_spot: 142
# Images in class gray_blight: 1100
# Images in class red_spot: 1143
# Images in class anthracnose: 100
# Images in class brown_blight: 980
# Images in class helopeltis: 1010
# Images in class healthy: 1074
# Images in class bird_eye_spot: 100
# Images in class algal_spot: 1113

# %%
train_batch = 16
val_batch = 16
img_height = 224
img_width = 224
IMG_SIZE = (img_height, img_width)
val_split = 0.2

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(dataset_dir,
                                                       validation_split=val_split,
                                                       subset="training",
                                                       seed=123,
                                                       image_size=(img_height, img_width),
                                                       batch_size=train_batch
                                                      )
# Out:
# Found 6762 files belonging to 9 classes.
# Using 5410 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(dataset_dir,                                                            
                                                     validation_split=val_split,                                                            
                                                     subset="validation",                                                     
                                                     seed=123,                                                     
                                                     image_size=(img_height, img_width),                                                     
                                                     batch_size=val_batch                                                           
                                                    )
# Out:
# Found 6762 files belonging to 9 classes.
# Using 1352 files for validation.

# %%
train_ds.class_names
# Out:
# ['algal_spot',
#  'anthracnose',
#  'bird_eye_spot',
#  'brown_blight',
#  'gray_blight',
#  'healthy',
#  'helopeltis',
#  'red_spot',
#  'white_spot']

# %%
class_names = train_ds.class_names
print(class_names)

num_classes=len(class_names)
# Out:
# ['algal_spot', 'anthracnose', 'bird_eye_spot', 'brown_blight', 'gray_blight', 'healthy', 'helopeltis', 'red_spot', 'white_spot']

# %%
# plt.figure(figsize=(10, 10))
# for images, labels in train_ds.take(1):
#     for i in range(9):
#         ax = plt.subplot(3, 3, i + 1)
#         plt.imshow(images[i].numpy().astype("uint8"))
#         plt.title(class_names[labels[i]])
#         plt.axis("off")

# %%
train_ds.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal",input_shape=(img_height,img_width,3)),
    layers.RandomFlip("vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
])

# %%
# Its a custom CNN model


model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(num_classes)
])

# %%
from keras.models import Model
from keras.layers import Dense,Flatten
from keras.applications import vgg16
from keras import backend as K

modelVGG = vgg16.VGG16(weights='imagenet', include_top=True)
modelVGG.trainable=False

modelVGG.input

modelVGG.summary(line_length=150)

modelVGG.layers.pop()
modelVGG.layers.pop()

modelVGG.summary(line_length=150)

new_layer = Dense(9, activation='softmax', name='my_dense')

inp = modelVGG.input
out = new_layer(modelVGG.layers[-1].output)

model = Model(inp, out)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 18s 0us/step
# Model: "vgg16"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                      Output Shape                                                Param #
# ======================================================================================================================================================
#  input_1 (InputLayer)                                              [(None, 224, 224, 3)]                                       0
#
#  block1_conv1 (Conv2D)                                             (None, 224, 224, 64)                                        1792
#
#  block1_conv2 (Conv2D)                                             (None, 224, 224, 64)                                        36928
#
#  block1_pool (MaxPooling2D)                                        (None, 112, 112, 64)                                        0
#
#  block2_conv1 (Conv2D)                                             (None, 112, 112, 128)                                       73856
#
#  block2_conv2 (Conv2D)                                             (None, 112, 112, 128)                                       147584
#
#  block2_pool (MaxPooling2D)                                        (None, 56, 56, 128)                                         0
#
#  block3_conv1 (Conv2D)                                             (None, 56, 56, 256)                                         295168
#
#  block3_conv2 (Conv2D)                                             (None, 56, 56, 256)                                         590080
#
#  block3_conv3 (Conv2D)                                             (None, 56, 56, 256)                                         590080
#
#  block3_pool (MaxPooling2D)                                        (None, 28, 28, 256)                                         0
#
#  block4_conv1 (Conv2D)                                             (None, 28, 28, 512)                                         1180160
#
#  block4_conv2 (Conv2D)                                             (None, 28, 28, 512)                                         2359808
#
#  block4_conv3 (Conv2D)                                             (None, 28, 28, 512)                                         2359808
#
#  block4_pool (MaxPooling2D)                                        (None, 14, 14, 512)                                         0
#
#  block5_conv1 (Conv2D)                                             (None, 14, 14, 512)                                         2359808
#
#  block5_conv2 (Conv2D)                                             (None, 14, 14, 512)                                         2359808
#
#  block5_conv3 (Conv2D)                                             (None, 14, 14, 512)                                         2359808
#
#  block5_pool (MaxPooling2D)                                        (None, 7, 7, 512)                                           0
#
#  flatten (Flatten)                                                 (None, 25088)                                               0
#
#  fc1 (Dense)                                                       (None, 4096)                                                102764544
#
#  fc2 (Dense)                                                       (None, 4096)                                                16781312
#
#  predictions (Dense)                                               (None, 1000)                                                4097000
#
# ======================================================================================================================================================
# Total params: 138,357,544
# Trainable params: 0
# Non-trainable params: 138,357,544
# ______________________________________________________________________________________________________________________________________________________
# Model: "vgg16"
# ______________________________________________________________________________________________________________________________________________________
#  Layer (type)                                                      Output Shape                                                Param #
# ======================================================================================================================================================
#  input_1 (InputLayer)                                              [(None, 224, 224, 3)]                                       0
#
#  block1_conv1 (Conv2D)                                             (None, 224, 224, 64)                                        1792
#
#  block1_conv2 (Conv2D)                                             (None, 224, 224, 64)                                        36928
#
#  block1_pool (MaxPooling2D)                                        (None, 112, 112, 64)                                        0
#
#  block2_conv1 (Conv2D)                                             (None, 112, 112, 128)                                       73856
#
#  block2_conv2 (Conv2D)                                             (None, 112, 112, 128)                                       147584
#
#  block2_pool (MaxPooling2D)                                        (None, 56, 56, 128)                                         0
#
#  block3_conv1 (Conv2D)                                             (None, 56, 56, 256)                                         295168
#
#  block3_conv2 (Conv2D)                                             (None, 56, 56, 256)                                         590080
#
#  block3_conv3 (Conv2D)                                             (None, 56, 56, 256)                                         590080
#
#  block3_pool (MaxPooling2D)                                        (None, 28, 28, 256)                                         0
#
#  block4_conv1 (Conv2D)                                             (None, 28, 28, 512)                                         1180160
#
#  block4_conv2 (Conv2D)                                             (None, 28, 28, 512)                                         2359808
#
#  block4_conv3 (Conv2D)                                             (None, 28, 28, 512)                                         2359808
#
#  block4_pool (MaxPooling2D)                                        (None, 14, 14, 512)                                         0
#
#  block5_conv1 (Conv2D)                                             (None, 14, 14, 512)                                         2359808
#
#  block5_conv2 (Conv2D)                                             (None, 14, 14, 512)                                         2359808
#
#  block5_conv3 (Conv2D)                                             (None, 14, 14, 512)                                         2359808
#
#  block5_pool (MaxPooling2D)                                        (None, 7, 7, 512)                                           0
#
#  flatten (Flatten)                                                 (None, 25088)                                               0
#
#  fc1 (Dense)                                                       (None, 4096)                                                102764544
#
#  fc2 (Dense)                                                       (None, 4096)                                                16781312
#
#  predictions (Dense)                                               (None, 1000)                                                4097000
#
# ======================================================================================================================================================
# Total params: 138,357,544
# Trainable params: 0
# Non-trainable params: 138,357,544
# ______________________________________________________________________________________________________________________________________________________

# %%
base_learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
#  my_dense (Dense)            (None, 9)                 9009
#
# =================================================================
# Total params: 138,366,553
# Trainable params: 9,009
# Non-trainable params: 138,357,544
# _________________________________________________________________

# %%
epochs=50
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 339/339 [==============================] - 1439s 903ms/step - loss: 2.1909 - accuracy: 0.1512 - val_loss: 2.1844 - val_accuracy: 0.1561
# Epoch 2/50
# 339/339 [==============================] - 27s 80ms/step - loss: 2.1773 - accuracy: 0.1634 - val_loss: 2.1719 - val_accuracy: 0.1612
# Epoch 3/50
# 339/339 [==============================] - 32s 95ms/step - loss: 2.1646 - accuracy: 0.1684 - val_loss: 2.1604 - val_accuracy: 0.1686
# Epoch 4/50
# 339/339 [==============================] - 27s 80ms/step - loss: 2.1528 - accuracy: 0.1782 - val_loss: 2.1496 - val_accuracy: 0.1731
# Epoch 5/50
# 339/339 [==============================] - 27s 80ms/step - loss: 2.1418 - accuracy: 0.1871 - val_loss: 2.1396 - val_accuracy: 0.1783
# Epoch 6/50
# 339/339 [==============================] - 27s 80ms/step - loss: 2.1315 - accuracy: 0.1998 - val_loss: 2.1303 - val_accuracy: 0.1842
# Epoch 7/50
# 339/339 [==============================] - 27s 80ms/step - loss: 2.1219 - accuracy: 0.2076 - val_loss: 2.1217 - val_accuracy: 0.1908
# Epoch 8/50
# 339/339 [==============================] - 28s 81ms/step - loss: 2.1130 - accuracy: 0.2133 - val_loss: 2.1136 - val_accuracy: 0.1960
# Epoch 9/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.1046 - accuracy: 0.2216 - val_loss: 2.1060 - val_accuracy: 0.2012
# Epoch 10/50
# 339/339 [==============================] - 28s 82ms/step - loss: 2.0967 - accuracy: 0.2248 - val_loss: 2.0989 - val_accuracy: 0.2041
# Epoch 11/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0893 - accuracy: 0.2270 - val_loss: 2.0922 - val_accuracy: 0.2049
# Epoch 12/50
# 339/339 [==============================] - 33s 96ms/step - loss: 2.0824 - accuracy: 0.2285 - val_loss: 2.0860 - val_accuracy: 0.2093
# Epoch 13/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0758 - accuracy: 0.2290 - val_loss: 2.0801 - val_accuracy: 0.2130
# Epoch 14/50
# 339/339 [==============================] - 28s 82ms/step - loss: 2.0697 - accuracy: 0.2312 - val_loss: 2.0746 - val_accuracy: 0.2138
# Epoch 15/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0639 - accuracy: 0.2318 - val_loss: 2.0694 - val_accuracy: 0.2145
# Epoch 16/50
# 339/339 [==============================] - 28s 84ms/step - loss: 2.0584 - accuracy: 0.2320 - val_loss: 2.0645 - val_accuracy: 0.2130
# Epoch 17/50
# 339/339 [==============================] - 28s 82ms/step - loss: 2.0532 - accuracy: 0.2342 - val_loss: 2.0599 - val_accuracy: 0.2123
# Epoch 18/50
# 339/339 [==============================] - 33s 97ms/step - loss: 2.0483 - accuracy: 0.2348 - val_loss: 2.0555 - val_accuracy: 0.2130
# Epoch 19/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0436 - accuracy: 0.2346 - val_loss: 2.0514 - val_accuracy: 0.2130
# Epoch 20/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0392 - accuracy: 0.2370 - val_loss: 2.0474 - val_accuracy: 0.2138
# Epoch 21/50
# 339/339 [==============================] - 28s 84ms/step - loss: 2.0351 - accuracy: 0.2373 - val_loss: 2.0437 - val_accuracy: 0.2145
# Epoch 22/50
# 339/339 [==============================] - 28s 84ms/step - loss: 2.0311 - accuracy: 0.2377 - val_loss: 2.0402 - val_accuracy: 0.2160
# Epoch 23/50
# 339/339 [==============================] - 28s 84ms/step - loss: 2.0273 - accuracy: 0.2394 - val_loss: 2.0368 - val_accuracy: 0.2152
# Epoch 24/50
# 339/339 [==============================] - 28s 82ms/step - loss: 2.0237 - accuracy: 0.2388 - val_loss: 2.0336 - val_accuracy: 0.2167
# Epoch 25/50
# 339/339 [==============================] - 28s 82ms/step - loss: 2.0202 - accuracy: 0.2409 - val_loss: 2.0306 - val_accuracy: 0.2167
# Epoch 26/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0170 - accuracy: 0.2396 - val_loss: 2.0277 - val_accuracy: 0.2167
# Epoch 27/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0138 - accuracy: 0.2410 - val_loss: 2.0249 - val_accuracy: 0.2167
# Epoch 28/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0108 - accuracy: 0.2405 - val_loss: 2.0223 - val_accuracy: 0.2167
# Epoch 29/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0080 - accuracy: 0.2416 - val_loss: 2.0198 - val_accuracy: 0.2189
# Epoch 30/50
# 339/339 [==============================] - 28s 84ms/step - loss: 2.0052 - accuracy: 0.2425 - val_loss: 2.0173 - val_accuracy: 0.2204
# Epoch 31/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0026 - accuracy: 0.2425 - val_loss: 2.0150 - val_accuracy: 0.2219
# Epoch 32/50
# 339/339 [==============================] - 28s 83ms/step - loss: 2.0001 - accuracy: 0.2438 - val_loss: 2.0128 - val_accuracy: 0.2226
# Epoch 33/50
# 339/339 [==============================] - 28s 84ms/step - loss: 1.9976 - accuracy: 0.2418 - val_loss: 2.0107 - val_accuracy: 0.2226
# Epoch 34/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9953 - accuracy: 0.2425 - val_loss: 2.0087 - val_accuracy: 0.2219
# Epoch 35/50
# 339/339 [==============================] - 33s 97ms/step - loss: 1.9931 - accuracy: 0.2421 - val_loss: 2.0067 - val_accuracy: 0.2226
# Epoch 36/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9909 - accuracy: 0.2433 - val_loss: 2.0048 - val_accuracy: 0.2226
# Epoch 37/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9889 - accuracy: 0.2434 - val_loss: 2.0030 - val_accuracy: 0.2219
# Epoch 38/50
# 339/339 [==============================] - 33s 97ms/step - loss: 1.9869 - accuracy: 0.2434 - val_loss: 2.0013 - val_accuracy: 0.2226
# Epoch 39/50
# 339/339 [==============================] - 33s 96ms/step - loss: 1.9849 - accuracy: 0.2427 - val_loss: 1.9996 - val_accuracy: 0.2241
# Epoch 40/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9831 - accuracy: 0.2444 - val_loss: 1.9980 - val_accuracy: 0.2249
# Epoch 41/50
# 339/339 [==============================] - 28s 82ms/step - loss: 1.9813 - accuracy: 0.2442 - val_loss: 1.9964 - val_accuracy: 0.2249
# Epoch 42/50
# 339/339 [==============================] - 28s 82ms/step - loss: 1.9796 - accuracy: 0.2449 - val_loss: 1.9949 - val_accuracy: 0.2256
# Epoch 43/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9779 - accuracy: 0.2451 - val_loss: 1.9934 - val_accuracy: 0.2256
# Epoch 44/50
# 339/339 [==============================] - 33s 97ms/step - loss: 1.9763 - accuracy: 0.2447 - val_loss: 1.9920 - val_accuracy: 0.2263
# Epoch 45/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9747 - accuracy: 0.2462 - val_loss: 1.9907 - val_accuracy: 0.2256
# Epoch 46/50
# 339/339 [==============================] - 28s 82ms/step - loss: 1.9732 - accuracy: 0.2475 - val_loss: 1.9893 - val_accuracy: 0.2263
# Epoch 47/50
# 339/339 [==============================] - 28s 82ms/step - loss: 1.9717 - accuracy: 0.2495 - val_loss: 1.9881 - val_accuracy: 0.2256
# Epoch 48/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9703 - accuracy: 0.2506 - val_loss: 1.9868 - val_accuracy: 0.2278
# Epoch 49/50
# 339/339 [==============================] - 28s 82ms/step - loss: 1.9689 - accuracy: 0.2506 - val_loss: 1.9856 - val_accuracy: 0.2300
# Epoch 50/50
# 339/339 [==============================] - 28s 83ms/step - loss: 1.9676 - accuracy: 0.2503 - val_loss: 1.9845 - val_accuracy: 0.2300

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
print(acc)
print(val_acc)

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
# Out:
# [0.15120147168636322, 0.16340111196041107, 0.1683918684720993, 0.1781885325908661, 0.18706099689006805, 0.19981515407562256, 0.20757855474948883, 0.2133086919784546, 0.2216266244649887, 0.22476895153522491, 0.2269870638847351, 0.22846581041812897, 0.22902032732963562, 0.231238454580307, 0.23179297149181366, 0.23197782039642334, 0.23419593274593353, 0.23475046455860138, 0.2345656156539917, 0.23696857690811157, 0.23733825981616974, 0.2377079427242279, 0.23937153816223145, 0.2388170063495636, 0.2408502846956253, 0.23955637216567993, 0.2410351186990738, 0.24048058688640594, 0.24158965051174164, 0.24251386523246765, 0.24251386523246765, 0.24380776286125183, 0.24177448451519012, 0.24251386523246765, 0.24214418232440948, 0.24325323104858398, 0.24343807995319366, 0.24343807995319366, 0.24269869923591614, 0.24436229467391968, 0.24417744576931, 0.24491682648658752, 0.245101660490036, 0.24473197758197784, 0.2462107241153717, 0.24750462174415588, 0.2495379000902176, 0.2506469488143921, 0.2506469488143921, 0.25027725100517273]
# [0.15606509149074554, 0.16124260425567627, 0.16863904893398285, 0.17307692766189575, 0.17825444042682648, 0.18417160212993622, 0.19082839787006378, 0.1960059106349945, 0.20118343830108643, 0.2041420191526413, 0.20488165318965912, 0.20931953191757202, 0.21301774680614471, 0.21375739574432373, 0.21449704468250275, 0.21301774680614471, 0.2122781127691269, 0.21301774680614471, 0.21301774680614471, 0.21375739574432373, 0.21449704468250275, 0.21597632765769958, 0.21523669362068176, 0.2167159765958786, 0.2167159765958786, 0.2167159765958786, 0.2167159765958786, 0.2167159765958786, 0.21893490850925446, 0.2204142063856125, 0.22189348936080933, 0.22263313829898834, 0.22263313829898834, 0.22189348936080933, 0.22263313829898834, 0.22263313829898834, 0.22189348936080933, 0.22263313829898834, 0.22411242127418518, 0.2248520702123642, 0.2248520702123642, 0.2255917191505432, 0.2255917191505432, 0.22633136808872223, 0.2255917191505432, 0.22633136808872223, 0.2255917191505432, 0.22781065106391907, 0.23002958297729492, 0.23002958297729492]

# %%
image_batch, label_batch = val_ds.as_numpy_iterator().next()
predictions = model.predict_on_batch(image_batch)

class_predictions = []
for i in predictions:
    class_prediction = np.argmax(i)
    class_predictions.append(class_prediction)

class_predictions = np.array(class_predictions)
print('Predictions:\n', class_predictions)
print('Labels:\n', label_batch)
print()
print(classification_report(label_batch, class_predictions))

plt.figure(figsize=(10, 21))
for i in range(15):
    ax = plt.subplot(5, 3, i + 1)
    plt.imshow(image_batch[i].astype("uint8"))
    plt.title("Prediction: "+class_names[class_predictions[i]]+"\nLabel: "+class_names[label_batch[i]])
    plt.axis("off")

history_df = pd.DataFrame(history.history)
history_df.to_csv("history.csv")
history_df.tail()
# Out:
# Predictions:
#  [7 0 0 0 0 7 7 0 0 0 7 0 0 7 7 7]
# Labels:
#  [0 4 5 6 5 4 6 3 7 6 0 0 0 6 7 5]
#
#               precision    recall  f1-score   support
#
#            0       0.22      0.50      0.31         4
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         2
#            5       0.00      0.00      0.00         3
#            6       0.00      0.00      0.00         4
#            7       0.14      0.50      0.22         2
#
#     accuracy                           0.19        16
#    macro avg       0.06      0.17      0.09        16
# weighted avg       0.07      0.19      0.10        16
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#         loss  accuracy  val_loss  val_accuracy
# 45  1.973192  0.247505  1.989341      0.226331
# 46  1.971720  0.249538  1.988063      0.225592
# 47  1.970299  0.250647  1.986827      0.227811
# 48  1.968913  0.250647  1.985628      0.230030
# 49  1.967575  0.250277  1.984464      0.230030
